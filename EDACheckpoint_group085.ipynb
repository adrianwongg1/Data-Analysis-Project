# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Adrian Wong
# - Kevin Kuang
# - Valerie Nguyen
# - Peter Nguyen
# - Bryan Cho

# %% [markdown]
# # Research Question

# %% [markdown]
# Given that the Super Bowl is the most viewed television program every year, there is huge emphasis on the advertisements shown, as well as choosing the performer for the Halftime show. We wanted to explore the following question: What is the relationship of a Super Bowl Halftime show performer's popularity by streams and stocks of food and beverage products such as Coors Light, Bud Light, M&Ms, Oreos, and Doritos featured in Super Bowl advertisements?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The Super Bowl, an annual championship game of the National Football League (NFL), is not only a significant sporting event but also a cultural phenomenon with a massive global audience. Alongside the game itself, the Super Bowl halftime show has emerged as a highly anticipated spectacle, featuring performances by some of the world's most renowned musical artists. With millions of viewers tuning in each year, the halftime show presents a unique opportunity for companies to showcase their brands through advertisements aired during the event. However, beyond the entertainment value and marketing, a question arises: what is the relationship between the popularity of halftime show performers and the sales impact on companies who advertise during the Super Bowl?
#
# Previous work has been doen on analyzing the influence of advertisements on sales without considering halftime show performer by highradius. They found that the effects of super bowl advertisements vary depending on the type of company and their relationship to others. An example of this is when two competing brands in the same industry air advertisements during the superbowl (Cola and Pepsi), they made no substantial gain on investments1. In contrast media companies like Fox, saw a 10% increase on total revenue from the previous year 1. In addition, they found that companies have been hesitant to invest into a super bowl advertisement as the price tag is hefty. The variation in amount of revenue between the companies suggested that there is no clear answer to is the advertisement a worth investment for companies, but they can potentially generate lots of money.
#
# INFORMS' article expands on this potential to generate high volumes of money by pointing out that companies participating in Super Bowl adds not only see a sharp increase in revenue leading up to the event, but that these numbers tend persist into to the NCAA's "March Madness," the NBA, and MLB games which all fall nicely into a timeline. This is particularly shown with Budweiser's ten-point increase in ratings around the Super Bowl, while a company like Coca-Cola whose ads are not associated with the event remain relatively stagnant 2. These findings reveal that it might also be important to anaylze data from the other fiscal quarters outside of the Super Bowl if we wish to find the a true relationship between Halftime Show popularity and said ads.
#
# The EU Business School also reveals that halftime show popularity is heavily influenced by a celebrity's timeline in popculture, which is a factor the Superbowl must be able to leverage. Rihanna, specifically, generated more anticipation than usual performers due to her stance on police brutality and her absence in the years leading up to her appearance. Apple Music reaped thee benefits of her comeback with their decision to sponsor the show for the first time 3, including her image and voice in their YouTube upload to maximize their exposure. With Superbowl viewership peaking during the Halftime Show, people are drawn in by the featured celebrity's relevance, in society and politics which provides a positive correlation for viewership of the entire event. Thus, it is clear the Halftime Show brings alluring opportunies for companies to increase their popularity, and the variance in popularity across different years affect which ads are promoted and the sales immediately following the performance.
#
# ^ February, T. (2024, April 18). Finance Newsletter: Super Bowl ad impacts. HighRadiusTM | Integrated Receivables | a/R Management Software. https://www.highradius.com/finsider/super-bowl-advertising-financial-impact/
# ^ Informs. (n.d.). Are super bowl ads worth it? new research indicates sales benefits persist well into the year during “March madness,” MLB and NBA Games. INFORMS. https://www.informs.org/News-Room/INFORMS-Releases/News-Releases/Are-Super-Bowl-ads-worth-it-New-research-indicates-sales-benefits-persist-well-into-the-year-during-March-Madness-MLB-and-NBA-games
# ^ Paz, E. (2023, March). All of the lights: Social and cultural implications of the Super Bowl Halftime Show. https://research.euruni.edu/Htdocs/Files/v/9990.pdf/ONResearch/March-2023---Elisa-Paz---FT-1.pdf

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We predict that the more popular the performer is, the higher sales of products are going to be for companies that advertise during the Super Bowl. We believe this to be true because a more popular performer can encourage viewers to stay and watch the game, Halftime show, and the advertisements in between versus a less popular performer dissuades viewers to stay for the duration of the game.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - Dataset #2 (if you have more than one!)
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - etc
#
# Now write 2 - 5 sentences describing each dataset here. Include a short description of the important variables in the dataset; what the metrics and datatypes are, what concepts they may be proxies for. Include information about how you would need to wrangle/clean/preprocess the dataset
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast
pepsi = pd.read_csv('PEP.csv')
coors_light = pd.read_csv('TAP.csv')
bud_light = pd.read_csv('ABI.BR.csv')
oreo = pd.read_csv('MDLZ.csv')
list = ['a','b','c','d','e','f','g','h','i','j','k']
df = pd.DataFrame()
for i in list:
    curr = pd.read_csv('data/splita'+i+'.csv')
    df = pd.concat([df,curr])
charts = df

# %% [markdown]
# ## Dataset #1 Charts

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
charts.head()
# Out:
#          date country  position  streams                track_id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# ...

# %% [markdown]
# Our first dataset is a collection of artists and the streams they had for a certain track at a certain date. We will clean this by isolating the years for each track first. Then we will groupby the artists names and years so we can find out how many streams they had per year. There are about 100,000 rows in this dataset and 10 variables. The important variables in this dataset is the streams, date, and artist. https://www.kaggle.com/datasets/jfreyberg/spotify-chart-data?resource=download

# %% [markdown]
# # Description of multiple Datasets:
# All of these Datasets of food/beverage companies will provide the data for the stock price before the Super Bowl and after the Super Bowl

# %% [markdown]
# ## Dataset #2 Pepsi

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
pepsi.insert(0, 'Company', 'PEP')
pepsi.head()
# Out:
#   Company        Date       Open       High        Low      Close  Adj Close  \
# 0     PEP  2015-01-02  94.930000  95.339996  94.050003  94.440002  72.306297
# 1     PEP  2015-01-05  94.449997  95.050003  93.720001  93.730003  71.762711
# 2     PEP  2015-01-06  94.080002  94.620003  92.940002  93.019997  71.219086
# 3     PEP  2015-01-07  95.129997  96.230003  94.430000  95.739998  73.301628
# 4     PEP  2015-01-08  96.739998  97.910004  96.680000  97.480003  74.633820
#
#     Volume
# 0  3545700
# 1  6441000
# 2  6195000
# 3  6526300
# 4  7131600

# %%
pepsi['Date'] = pd.to_datetime(pepsi['Date'])
february_pepsi = pepsi[(pepsi['Date'].dt.month == 2) | (pepsi['Date'].dt.month == 1) | (pepsi['Date'].dt.month == 3)]
february_pepsi.head()
# Out:
#   Company       Date       Open       High        Low      Close  Adj Close  \
# 0     PEP 2015-01-02  94.930000  95.339996  94.050003  94.440002  72.306297
# 1     PEP 2015-01-05  94.449997  95.050003  93.720001  93.730003  71.762711
# 2     PEP 2015-01-06  94.080002  94.620003  92.940002  93.019997  71.219086
# 3     PEP 2015-01-07  95.129997  96.230003  94.430000  95.739998  73.301628
# 4     PEP 2015-01-08  96.739998  97.910004  96.680000  97.480003  74.633820
#
#     Volume
# 0  3545700
# 1  6441000
# 2  6195000
# 3  6526300
# 4  7131600

# %% [markdown]
# This is Pepsi's stock price filtered by the month of February, and we will find the difference between the open and the close price at a certain date where the super bowl is occuring. There are 192 rows and 7 variables.

# %% [markdown]
# ## Dataset #3 Coors Light

# %%
coors_light.insert(0,'Company','TAP')
coors_light.head()
# Out:
#   Company        Date       Open       High        Low      Close  Adj Close  \
# 0     TAP  2015-01-02  74.639999  74.889999  72.940002  73.860001  60.016758
# 1     TAP  2015-01-05  73.389999  74.220001  73.279999  73.410004  59.651096
# 2     TAP  2015-01-06  73.910004  74.360001  72.400002  73.059998  59.366688
# 3     TAP  2015-01-07  74.000000  75.540001  73.940002  75.400002  61.268120
# 4     TAP  2015-01-08  77.040001  78.050003  77.029999  77.730003  63.161434
#
#     Volume
# 0   811100
# 1  1288400
# 2  1358800
# 3  1507700
# 4  1810700

# %%
coors_light['Date'] = pd.to_datetime(coors_light['Date'])
february_coors_light = coors_light[(coors_light['Date'].dt.month == 2) | (coors_light['Date'].dt.month == 1) | (coors_light['Date'].dt.month == 3)]
february_coors_light.head()
# Out:
#   Company       Date       Open       High        Low      Close  Adj Close  \
# 0     TAP 2015-01-02  74.639999  74.889999  72.940002  73.860001  60.016758
# 1     TAP 2015-01-05  73.389999  74.220001  73.279999  73.410004  59.651096
# 2     TAP 2015-01-06  73.910004  74.360001  72.400002  73.059998  59.366688
# 3     TAP 2015-01-07  74.000000  75.540001  73.940002  75.400002  61.268120
# 4     TAP 2015-01-08  77.040001  78.050003  77.029999  77.730003  63.161434
#
#     Volume
# 0   811100
# 1  1288400
# 2  1358800
# 3  1507700
# 4  1810700

# %% [markdown]
# This is Coors Light's stock price filtered by the month of February, and we will find the difference between the open and the close price at a certain date where the super bowl is occuring. There are 192 rows and 7 variables.

# %% [markdown]
# ## Dataset #4 Bud Light

# %%
bud_light.insert(0, 'Company', 'ABI.BR')
bud_light.head()
# Out:
#   Company        Date       Open       High        Low      Close  Adj Close  \
# 0  ABI.BR  2015-01-02  93.980003  94.550003  92.440002  92.650002  74.487869
# 1  ABI.BR  2015-01-05  92.300003  93.889999  90.580002  90.580002  72.823654
# 2  ABI.BR  2015-01-06  90.459999  90.660004  89.570000  89.680000  72.100090
# 3  ABI.BR  2015-01-07  90.699997  92.809998  90.290001  91.860001  73.852737
# 4  ABI.BR  2015-01-08  93.629997  96.410004  93.120003  96.410004  77.510826
#
#     Volume
# 0   961762
# 1  2094548
# 2  2007889
# 3  2165256
# 4  2624543

# %%
bud_light['Date'] = pd.to_datetime(bud_light['Date'])
february_bud_light = bud_light[(bud_light['Date'].dt.month == 2) | (bud_light['Date'].dt.month == 1) | (bud_light['Date'].dt.month == 3)]
february_bud_light.head()
# Out:
#   Company       Date       Open       High        Low      Close  Adj Close  \
# 0  ABI.BR 2015-01-02  93.980003  94.550003  92.440002  92.650002  74.487869
# 1  ABI.BR 2015-01-05  92.300003  93.889999  90.580002  90.580002  72.823654
# 2  ABI.BR 2015-01-06  90.459999  90.660004  89.570000  89.680000  72.100090
# 3  ABI.BR 2015-01-07  90.699997  92.809998  90.290001  91.860001  73.852737
# 4  ABI.BR 2015-01-08  93.629997  96.410004  93.120003  96.410004  77.510826
#
#     Volume
# 0   961762
# 1  2094548
# 2  2007889
# 3  2165256
# 4  2624543

# %% [markdown]
# This is Bud Light's stock price filtered by the month of February, and we will find the difference between the open and the close price at a certain date where the super bowl is occuring. There are 192 rows and 7 variables.

# %% [markdown]
# ## Dataset #5 Oreo

# %%
oreo.insert(0, 'Company', 'MDLZ')
oreo.head()
# Out:
#   Company        Date       Open       High        Low      Close  Adj Close  \
# 0    MDLZ  2015-01-02  36.430000  36.939999  36.270000  36.790001  30.354666
# 1    MDLZ  2015-01-05  36.709999  36.770000  36.119999  36.240002  29.900888
# 2    MDLZ  2015-01-06  36.369999  36.650002  35.790001  35.990002  29.694613
# 3    MDLZ  2015-01-07  36.189999  37.200001  35.970001  37.119999  30.626944
# 4    MDLZ  2015-01-08  37.090000  37.880001  37.090000  37.590000  31.014727
#
#      Volume
# 0   7707700
# 1   9621100
# 2   7669500
# 3  10418800
# 4   8122100

# %%
oreo['Date'] = pd.to_datetime(oreo['Date'])
february_oreo = oreo[(oreo['Date'].dt.month == 2) | (oreo['Date'].dt.month == 1) | (oreo['Date'].dt.month == 3)]
february_oreo.head()
february_oreo.shape
# Out:
# (614, 8)

# %% [markdown]
# This is Oreos's stock price filtered by the month of February, and we will find the difference between the open and the close price at a certain date where the super bowl is occuring. There are 192 rows and 7 variables.

# %%
merged_beer = pd.concat([february_coors_light, february_bud_light], ignore_index=True)
merged_beer.sort_values(by='Date')
# Out:
#      Company       Date       Open       High        Low      Close  \
# 0        TAP 2015-01-02  74.639999  74.889999  72.940002  73.860001
# 614   ABI.BR 2015-01-02  93.980003  94.550003  92.440002  92.650002
# 615   ABI.BR 2015-01-05  92.300003  93.889999  90.580002  90.580002
# 1        TAP 2015-01-05  73.389999  74.220001  73.279999  73.410004
# 2        TAP 2015-01-06  73.910004  74.360001  72.400002  73.059998
# ...      ...        ...        ...        ...        ...        ...
# 1246  ABI.BR 2024-03-26  55.310001  55.910000  55.139999  55.820000
# 1247  ABI.BR 2024-03-27  55.900002  56.459999  55.900002  56.250000
# 612      TAP 2024-03-27  67.199997  67.720001  67.010002  67.339996
# 613      TAP 2024-03-28  67.570000  67.779999  66.940002  67.250000
# 1248  ABI.BR 2024-03-28  56.169998  56.480000  55.639999  56.459999
#
#       Adj Close   Volume
# 0     60.016758   811100
# 614   74.487869   961762
# 615   72.823654  2094548
# 1     59.651096  1288400
# ...

# %%
merged_snack = pd.concat([february_pepsi, february_oreo], ignore_index=True)
merged_snack.sort_values(by='Date')
# Out:
#      Company       Date        Open        High         Low       Close  \
# 0        PEP 2015-01-02   94.930000   95.339996   94.050003   94.440002
# 614     MDLZ 2015-01-02   36.430000   36.939999   36.270000   36.790001
# 615     MDLZ 2015-01-05   36.709999   36.770000   36.119999   36.240002
# 1        PEP 2015-01-05   94.449997   95.050003   93.720001   93.730003
# 2        PEP 2015-01-06   94.080002   94.620003   92.940002   93.019997
# ...      ...        ...         ...         ...         ...         ...
# 611      PEP 2024-03-26  172.169998  172.970001  171.820007  172.729996
# 1226    MDLZ 2024-03-27   70.050003   70.349998   69.830002   70.099998
# 612      PEP 2024-03-27  174.000000  174.690002  173.050003  173.570007
# 613      PEP 2024-03-28  174.759995  175.809998  174.369995  175.009995
# 1227    MDLZ 2024-03-28   70.470001   70.580002   69.830002   70.000000
#
#        Adj Close   Volume
# 0      72.306297  3545700
# 614    30.354666  7707700
# ...

# %%
all_february = pd.concat([merged_beer, merged_snack])
all_february = all_february.sort_values(by='Date', ignore_index=True)
all_february.head()
# Out:
#   Company       Date       Open       High        Low      Close  Adj Close  \
# 0     TAP 2015-01-02  74.639999  74.889999  72.940002  73.860001  60.016758
# 1     PEP 2015-01-02  94.930000  95.339996  94.050003  94.440002  72.306297
# 2  ABI.BR 2015-01-02  93.980003  94.550003  92.440002  92.650002  74.487869
# 3    MDLZ 2015-01-02  36.430000  36.939999  36.270000  36.790001  30.354666
# 4  ABI.BR 2015-01-05  92.300003  93.889999  90.580002  90.580002  72.823654
#
#     Volume
# 0   811100
# 1  3545700
# 2   961762
# 3  7707700
# 4  2094548

# %%
artists_2024 = ['Usher', 'Alicia Keys', 'will.i.am', 'Jermaine Dupri', 'H.E.R.', 'will.i.am', 'Lil Jon', 'Ludacris']
sb_2024 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2024))]
sb_2024['date'] = sb_2024['date'].astype(str)
sb_2024['date'] = sb_2024['date'].str.replace('-', '/')
sb_2024['date'] = pd.to_datetime(sb_2024['date'])
sb_2024.head()
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1059663615.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2024['date'] = sb_2024['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1059663615.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2024['date'] = sb_2024['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1059663615.py:5: SettingWithCopyWarning:
# ...

# %%
sb_2023 = charts[charts['artists'].apply(lambda x: 'Rihanna' in x)]
sb_2023['date'] = sb_2023['date'].astype(str)
sb_2023['date'] = sb_2023['date'].str.replace('-', '/')
sb_2023['date'] = pd.to_datetime(sb_2023['date'])
sb_2023.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1531326369.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2023['date'] = sb_2023['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1531326369.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2023['date'] = sb_2023['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/1531326369.py:4: SettingWithCopyWarning:
# ...

# %%
artists_2022 = ['Eminem', 'Dr. Dre', 'Snoop Dogg', 'Kendrick Lamar', 'Mary J. Blige']
sb_2022 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2022))]
sb_2022['date'] = sb_2022['date'].astype(str)
sb_2022['date'] = sb_2022['date'].str.replace('-', '/')
sb_2022['date'] = pd.to_datetime(sb_2022['date'])
sb_2022.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2283354262.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2022['date'] = sb_2022['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2283354262.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2022['date'] = sb_2022['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2283354262.py:5: SettingWithCopyWarning:
# ...

# %%
sb_2021 = charts[charts['artists'].apply(lambda x: 'The Weeknd' in x)]
sb_2021['date'] = sb_2021['date'].astype(str)
sb_2021['date'] = sb_2021['date'].str.replace('-', '/')
sb_2021['date'] = pd.to_datetime(sb_2021['date'])
sb_2021.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3344998201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2021['date'] = sb_2021['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3344998201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2021['date'] = sb_2021['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3344998201.py:4: SettingWithCopyWarning:
# ...

# %%
artists_2020 = ['Shakira', 'Jennifer Lopez', 'Bad Bunny', 'J Balvin', 'Emme Muniz']
sb_2020 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2020))]
sb_2020['date'] = sb_2020['date'].astype(str)
sb_2020['date'] = sb_2020['date'].str.replace('-', '/')
sb_2020['date'] = pd.to_datetime(sb_2020['date'])
sb_2020.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3550175998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2020['date'] = sb_2020['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3550175998.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2020['date'] = sb_2020['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3550175998.py:5: SettingWithCopyWarning:
# ...

# %%
artists_2019 = ['Maroon 5', 'Travis Scott', 'Big Boi']
sb_2019 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2019))]
sb_2019['date'] = sb_2019['date'].astype(str)
sb_2019['date'] = sb_2019['date'].str.replace('-', '/')
sb_2019['date'] = pd.to_datetime(sb_2019['date'])
sb_2019.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2317262068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2019['date'] = sb_2019['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2317262068.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2019['date'] = sb_2019['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/2317262068.py:5: SettingWithCopyWarning:
# ...

# %%
artists_2018 = ['Justin Timberlake', 'The Tennessee Kids']
sb_2018 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2018))]
sb_2018['date'] = sb_2018['date'].astype(str)
sb_2018['date'] = sb_2018['date'].str.replace('-', '/')
sb_2018['date'] = pd.to_datetime(sb_2018['date'])
sb_2018.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/655884859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2018['date'] = sb_2018['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/655884859.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2018['date'] = sb_2018['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/655884859.py:5: SettingWithCopyWarning:
# ...

# %%
sb_2017 = charts[charts['artists'].apply(lambda x: 'Lady Gaga' in x)]
sb_2017['date'] = sb_2017['date'].astype(str)
sb_2017['date'] = sb_2017['date'].str.replace('-', '/')
sb_2017['date'] = pd.to_datetime(sb_2017['date'])
sb_2017.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/495758014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2017['date'] = sb_2017['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/495758014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2017['date'] = sb_2017['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/495758014.py:4: SettingWithCopyWarning:
# ...

# %%
artists_2016 = ['Coldplay', 'Beyoncé', 'Bruno Mars']
sb_2016 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2016))]
sb_2016['date'] = sb_2016['date'].astype(str)
sb_2016['date'] = sb_2016['date'].str.replace('-', '/')
sb_2016['date'] = pd.to_datetime(sb_2016['date'])
sb_2016.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3666948579.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2016['date'] = sb_2016['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3666948579.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2016['date'] = sb_2016['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3666948579.py:5: SettingWithCopyWarning:
# ...

# %%
artists_2015 = ['Katy Perry', 'Lenny Kravitz', 'Missy Elliott']
sb_2015 = charts[charts['artists'].apply(lambda x: any(artist in x for artist in artists_2015))]
sb_2015['date'] = sb_2015['date'].astype(str)
sb_2015['date'] = sb_2015['date'].str.replace('-', '/')
sb_2015['date'] = pd.to_datetime(sb_2015['date'])
sb_2015.shape
# Out:
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3272580848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2015['date'] = sb_2015['date'].astype(str)
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3272580848.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_2015['date'] = sb_2015['date'].str.replace('-', '/')
# /var/folders/sz/y68d39n508s6sq50h8pgm2dr0000gn/T/ipykernel_75748/3272580848.py:5: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# Carry out whatever EDA you need to for your project.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.

# %% [markdown]
# ### Section 1 of EDA - Trends of the Stock Closing Prices for Each Company
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

all_february['Year'] = all_february['Date'].dt.year
unique_years = all_february['Year'].unique()

for year in unique_years:
    plt.figure(figsize=(12, 6))
    plt.title(f'Stock Closing Prices Over Time - {year}')
    
    # data for the current year
    year_data = all_february[all_february['Year'] == year]
    
    for company in year_data['Company'].unique():
        company_data = year_data[year_data['Company'] == company]
        plt.plot(company_data['Date'].values, company_data['Close'].values, label=company)
    
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.legend()
    plt.show()

# %% [markdown]
# In order to gain a better understand of the trends of the stock closing prices, we plotted them for each of the companies and for each of the years. To be more specific, we are only looking at the month before the Super Bowl through the month after the Super Bowl, meaning January through March. Without taking into account the artists' popularity, we wanted to see if there would be any obvious spike or decrease in the stocks around the time of the Super Bowl.

# %% [markdown]
# Additionally, between the years we can observe different trend in the stock closing prices that might not be related to the Super Bowl. For example, in March of 2020, all of the companies had a significant drop in closing prices most likely due to the coronavirus. There are no other obvious trends between the other years, so it would be important for us to later analyze that accordingly when taking into account the popularity of the artists performing at the halftime show.

# %%
# Separate boxplots for each company and each year
for company in all_february['Company'].unique():
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='Year', y='Close', data=all_february[all_february['Company'] == company])
    plt.title(f'Boxplot of Stock Closing Prices for {company}')
    plt.xlabel('Year')
    plt.ylabel('Closing Price')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# In addition to looking at the line plot of the stock closing prices for each year (again for just the months of January - March), it is also important to look at trends for each of the companies. To do so, we plotted the box plot for each of the companies closing prices for each of the years. This allows us to see what how the range, minimum, maximum, and general distribution of their closing prices changed over the years. Some of the companies for certain years have outliers. This could be possible points that we might look for when analyzing the after effects of a company having ads in the Super Bowl with relation to the popularity of artists.

# %% [markdown]
# ### Section 2 of EDA Artists

# %%
artists_2015 = ['Katy Perry', 'Lenny Kravitz', 'Missy Elliott']
artists_2016 = ['Coldplay', 'Beyoncé', 'Bruno Mars']
artists_2017 = ['Lady Gaga']
artists_2018 = ['Justin Timberlake', 'The Tennessee Kids']
artists_2019 = ['Maroon 5', 'Travis Scott', 'Big Boi']
artists_2020 = ['Shakira', 'Jennifer Lopez', 'Bad Bunny', 'J Balvin', 'Emme Muniz']
artists_2021 = ['The Weeknd']
artists_2022 = ['Eminem', 'Dr. Dre', 'Snoop Dogg', 'Kendrick Lamar', 'Mary J. Blige']
# NEED TO APPEND ALL THE LISTS TOGETHER!!!!!! - do this peter
# then filter out artists that do not belong in the big set of artists created ^^^
combined = artists_2015 + artists_2016 + artists_2017 + artists_2018 + artists_2019 + artists_2020 + artists_2021 + artists_2022

def relevant(inputList):
    output = []
    for input in inputList:
        if input in combined:
            output.append(input)
    return output

# %%
charts['artists']= charts['artists'].apply(ast.literal_eval) #changes the artists column into actual list
charts = charts.drop(columns=['artist_genres','explicit','duration','country','track_id']) # filtering out the artists we do not need

# %%
filtered = charts
filtered['artists'] = filtered['artists'].apply(relevant)
filtered = filtered[filtered.get('artists').str.len() != 0]
filtered.head()
filtered.shape
# Out:
# (558010, 5)

# %%
testPos = filtered.explode('artists')
testPos['date'] = testPos['date'].str[:4]
testPos = testPos.drop(columns=['streams','name'])
testPos = testPos.groupby(['artists','date']).mean()
testPos = testPos.reset_index()
testPos = testPos.sort_values(by='date')
testPos.head()
# Out:
#                artists  date   position
# 101     Kendrick Lamar  2013  38.067797
# 71      Jennifer Lopez  2013  38.661290
# 60            J Balvin  2013  10.090909
# 81   Justin Timberlake  2013  23.584574
# 20          Bruno Mars  2013  29.250000

# %%
test = filtered.explode('artists')
test['date'] = test['date'].str[:4]
test = test.groupby(['artists','date']).sum()
test = test.reset_index().drop(columns=['name','position'])
test
# Out:
#           artists  date      streams
# 0       Bad Bunny  2016     13745006
# 1       Bad Bunny  2017   2084716143
# 2       Bad Bunny  2018   5990596807
# 3       Bad Bunny  2019   6054310469
# 4       Bad Bunny  2020  10017661037
# ..            ...   ...          ...
# 184  Travis Scott  2019   3898445146
# 185  Travis Scott  2020   4734437965
# 186  Travis Scott  2021   2120589287
# 187  Travis Scott  2022    514800418
# 188  Travis Scott  2023    200188191
#
# [189 rows x 3 columns]

# %%
test = test.sort_values(by='date')
test = test[test.get('date') != '2023'] # not enough data for all of 2023
test
# Out:
#                artists  date     streams
# 101     Kendrick Lamar  2013    14474340
# 71      Jennifer Lopez  2013     4159343
# 60            J Balvin  2013     2542125
# 81   Justin Timberlake  2013   159889754
# 20          Bruno Mars  2013    87631439
# ..                 ...   ...         ...
# 145      Missy Elliott  2022     2090841
# 69            J Balvin  2022  1140057601
# 17             Beyoncé  2022  1022254427
# 156            Shakira  2022   868280354
# 139      Mary J. Blige  2022      284519
#
# [177 rows x 3 columns]

# %%
for artist in test['artists'].unique():
    #fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
    plt.figure(figsize=(12,6))
    # plt.title(f'{artist} Streams Over Time')
    artist_data = test[test['artists'] == artist]
    plt.subplot(1,2,1)
    plt.plot(artist_data['date'].values, artist_data['streams'].values, label=artist)
    plt.title(f'{artist} Streams Over Time')
    plt.xlabel('Date')
    plt.ylabel('Streams')

    plt.subplot(1,2,2)
    plt.bar(artist_data['date'].values, artist_data['streams'].values, label=artist)
    plt.title(f'{artist} Streams Over Time')
    plt.xlabel('Date')
    plt.ylabel('Streams')
    plt.legend()
    plt.show()

# %% [markdown]
# # Analysis for total streams across the world for each artist
# Stepping into this set of data, we plotted the trend of total streams of songs from that made it to Spotify's top 100 popularity charts across various years, with the hope of recognizing a pattern between artists and specific years. Interestingly, both the line plots and bar charts reveal that certain artists undergo spikes in streams like Kendrick Lamar in 2017, while others face dips as well. This is certainly a point worth investigating as we try to draw a connection between the Super Bowl performance of artists and whether or not their apperances on the big stage correlate to any shifts in the norm on the plots.

# %%
for artist in testPos['artists'].unique():
    #fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
    plt.figure(figsize=(12,6))
    # plt.title(f'{artist} Streams Over Time')
    artist_data = testPos[testPos['artists'] == artist]
    plt.subplot(1,2,1)
    plt.plot(artist_data['date'].values, artist_data['position'].values, label=artist)
    plt.title(f'{artist} Average Position in Gobal Charts Over Time')
    plt.xlabel('Date')
    plt.ylabel('Position')

    plt.subplot(1,2,2)
    plt.bar(artist_data['date'].values, artist_data['position'].values, label=artist)
    plt.title(f'{artist} Average Position in Gobal Charts Over Time')
    plt.xlabel('Date')
    plt.ylabel('Position')
    plt.legend()
    plt.show()

# %% [markdown]
# # Analysis for average position in top charts around the world for each artist
#
# What took a very similar approach for artist popularity rankings as we did with streams. We plotted the trend of average position in worldwide charts of each artist that made it to Spotify's top 100 popularity charts across various years, with the hope of recognizing a pattern between artists and specific years. Interestingly, both the line plots and bar charts reveal that certain artists undergo spikes in streams like Kendrick Lamar in 2017, while others face dips as well. This gives us a nuanced approach different from looking at just the total streams because it allows us to see a different set of the popularity of the artist.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# There are a few factors that we must consider with respect to dealing with ethics and privacy when trying to answer our proposed research question. For example, certain companies may release more data on their sales in comparison to other companies, leading to potential biases in the dataset. In addition to skewed data regarding sales data, we might also encounter challenges when analyzing an artists' popularity. There are many factors that can be taken into account for an artists' popularity including, but not limited to streaming numbers, Spotify charts, and various awards. Because we can only focus on a limited number of factors, it is possible that our results aren't fully representative of an artists' popularity. Additionally, we must ensure that we are abiding by the terms of the data we use in order to avoid privacy issues. Because missing information might cause our data to be skewed and is something we can’t necessarily fix, it is important to be aware of how these biases might affect our analysis and to ensure that we are being transparent throughout the entire analysis process. In our findings, we will make sure to acknowledge the effects that potential skewed data might have on our conclusion.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# * Timely Communication
# * Work together on issues that need to be resolved
# * Use group chats to get team meetings scheduled

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 5/17  |  1 PM | Review Project Proposal feedback + identify key parts we need to revise | Continue background research and search for datasets we might want to use; Revise proposal for Data Checkpoint |
# | 5/24  |  1 PM |  Think about what wrangling and analytic approaches we might want to take with the dataset we used | Discuss approaches we thought about and assign group member to import/wrangle the data or work on EDA |
# | 5/31  | 1 PM  | Import and wrangle the data (team member to be assigned) and the rest will work on exploratory data analysis  | Discuss Wrangling and possible analytical approaches; Submit EDA Checkpoint|
# | 6/7  | 1 PM  | Review wrangling and EDA (identify aspects that we might want to change/expand on) | Discuss issues that members thought of and start working on analysis|
# | 6/10  | 1 PM  | Finish up the analysis and conclusion | Revise and review entire project |
# | 6/12  | Before 11:59 PM | N/A | Turn in Final Project + Surveys |
